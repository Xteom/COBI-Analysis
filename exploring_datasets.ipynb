# %% [markdown]
# # Primer acercamiento a datos de COBI
# [Objetivo 13: Acción por el Clima](https://www.un.org/sustainabledevelopment/es/climate-change-2/)
#
#
# 1.	Sensores oceanográficos (datos de variables climáticas) y producción pesquera. Como comentamos, nos gustaría cruzar datos de producción pesquera (Avisos de arribo) y la BD oceanograficos en las comunidades en las que tenemos sensores, en tres regiones: Pacífico, Golfo de California, Caribe mexicano. Sería interesante que revises el Objetivo de Desarrollo Sostenible 13 (acción por el clima) por si necesitas contexto.
# a.	Nosotros tenemos los datos.
# 2.	Considerando todas las comunidades en las que COBI ha trabajado (54 aprox, te confirmamos), nos gustaría tener una “foto” de cada comunidad: desde qué recursos pesqueros tienen, tienen agua potable o no, internet o no, luz, indice de escolaridad, marginación, etc.
# a.	Tenemos datos pesqueros, pero los demás datos hay que sacarlos de INEGI, etc.

# %%
import pandas as pd

# %%
# path pc: C:\Users\mateo\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\cobi_data\
# path surface: C:\Users\mateo.TABLET-PQBTM7BC\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\cobi_data\

surface = True

if surface:
    path = 'C:\\Users\\mateo.TABLET-PQBTM7BC\\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\\cobi_data\\'
else:
    path = 'C:\\Users\\mateo\\OneDrive - INSTITUTO TECNOLOGICO AUTONOMO DE MEXICO\\cobi_data\\'

# %%
avisos_df = pd.read_csv(f'{path}Avisos_arribo_Baja_California_2017-2021.csv', encoding='latin-1')
sites_df = pd.read_csv(f'{path}all_sites_miniDOT_data_09_2017-09_2018.csv')

# %%
avisos_df
# Out:
#        RNP ACTIVO  NOMBRE ACTIVO  CLAVE SITIO DESEMBARQUE  \
# 0             NaN            NaN                   201000
# 1             NaN            NaN                   201000
# 2             NaN            NaN                   201000
# 3             NaN            NaN                   201000
# 4             NaN            NaN                   201000
# ...           ...            ...                      ...
# 97450         NaN            NaN                   201000
# 97451         NaN            NaN                   201000
# 97452         NaN            NaN                   207112
# 97453         NaN            NaN                   207112
# 97454         NaN            NaN                   207112
#
#       NOMBRE SITIO DESEMBARQUE  RNPA UNIDAD ECONOMICA  \
# 0         BAHIA DE LOS ANGELES              203017116
# 1         BAHIA DE LOS ANGELES              203017116
# 2         BAHIA DE LOS ANGELES              203017116
# ...

# %%
sites_df
# Out:
#                UTC_date_time                      Local_time  Battery  \
# 0       2017-09-24T07:02:00Z             2017-09-24 00:02:00     3.49
# 1       2017-09-24T07:12:00Z             2017-09-24 00:12:00     3.49
# 2       2017-09-24T07:22:00Z             2017-09-24 00:22:00     3.49
# 3       2017-09-24T07:32:00Z             2017-09-24 00:32:00     3.49
# 4       2017-09-24T07:42:00Z             2017-09-24 00:42:00     3.49
# ...                      ...                             ...      ...
# 852360  2017-09-28T00:06:00Z             2017-09-27 18:06:00     3.47
# 852361  2017-09-28T00:16:00Z             2017-09-27 18:16:00     3.48
# 852362  2017-09-28T00:26:00Z             2017-09-27 18:26:00     3.48
# 852363  2017-09-28T00:36:00Z             2017-09-27 18:36:00     3.48
# 852364  2017-09-28T00:46:00Z             2017-09-27 18:46:00     3.48
#
#         Temperature  Dissolved.Oxygen  Dissolved.Oxygen.Saturation      Q  \
# ...

# %%
""" 
¿Cuántos días no se pesca?
¿Cuántos días no se pesca?
¿Cuántas especies hay? ¿Son únicas?
¿Cuándo sube/baja?
¿Cuándo sube/baja?
¿Cómo se distribuyen los datos de los sensores? ¿Hay seasonality, trends, etc.? ¿Con qué periodicidad?

"""

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('data\\arribos_BC_17_21.csv', encoding='latin1')

# Print the first 5 rows of the DataFrame
print(df.head())

# Get the shape of the DataFrame
print('Shape:', df.shape)

# Get information about the columns
print(df.info())

# Get basic statistics about the DataFrame
print(df.describe())

# Get the number of unique values in each column
print(df.nunique())

# Check for missing values in the DataFrame
print(df.isna().sum())

# # Create a scatter plot of two numeric columns
# df.plot(kind='scatter', x='numeric_column1', y='numeric_column2')

# # Create a bar chart of a categorical column
# df['categorical_column'].value_counts().plot(kind='bar')

# # Create a box plot of a numeric column
# df.boxplot(column='numeric_column')
# Out:
#    RNP ACTIVO  NOMBRE ACTIVO  CLAVE SITIO DESEMBARQUE  \
# 0         NaN            NaN                   201000
# 1         NaN            NaN                   201000
# 2         NaN            NaN                   201000
# 3         NaN            NaN                   201000
# 4         NaN            NaN                   201000
#
#   NOMBRE SITIO DESEMBARQUE  RNPA UNIDAD ECONOMICA  \
# 0     BAHIA DE LOS ANGELES              203017116
# 1     BAHIA DE LOS ANGELES              203017116
# 2     BAHIA DE LOS ANGELES              203017116
# 3     BAHIA DE LOS ANGELES              203127048
# 4     BAHIA DE LOS ANGELES              203127048
#
#                       UNIDAD ECONOMICA    NOMBRE ESTADO  CLAVE OFICINA  \
# 0  ANGELES DEL MAR DE CORTES SPR DE RL  BAJA CALIFORNIA            201
# 1  ANGELES DEL MAR DE CORTES SPR DE RL  BAJA CALIFORNIA            201
# 2  ANGELES DEL MAR DE CORTES SPR DE RL  BAJA CALIFORNIA            201
# ...
